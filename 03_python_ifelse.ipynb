# %% [markdown]
# #**Pythonda'da If-Else Yapısı**
# If_Else değişkenlerimizin içindeki değerlerin karşılaştırmasını yapan ve içeriğine göre işlemlerde değişiklik yapabilmemizi sağlayan özel bir yapıdır. If-else sayesinde kullanıcıların tercihlerine göre alternatif yazılımlar tasarlayabiliriz.

# %%
#Cinsiyete göre print yazısının değiştiği ufak deneme
#Boolean: 0 veya 1 değeri anlamına gelen ve sadece True (Doğru) veya False (Yanlış) değeri alan değişkenlerdir.
cinsiyet = True #True = Kadınlar // False = Erkekler
#If-Else
if cinsiyet == True:
  print("Hoşgeldiniz Kadınlar")
else:
  print("Hoşgeldiniz Erkekler")
print("Program bitti.")
# Out:
# Hoşgeldiniz Kadınlar
# Program bitti.

# %% [markdown]
# #If-Else Yapısının Açılaması
# If-Else yapısının yazımı aşağıdaki gibidir.
#
#
#
# ```
# if değişken_adı == değişkenin_kontrol_edileceği_değer:
# # DÖRT BOŞLUK BIRAKILIR VEYA TAB TUŞUNA BASILARAK if İÇİNE DEĞER YAZILIR.
#   Koşul sağlandığında çalışacak kodlar
# else: #DEĞİLSE ANLAMINA GELEN KOD BLOĞUDUR
# # DÖRT BOŞLUK BIRAKILIR VEYA TAB TUŞUNA BASILARAK if İÇİNE DEĞER YAZILIR.
#   Koşul sağlandığında çalışacak kodlar
# ```
# ## ÖNEMLİ NOKTALAR
# ---
#
# 1. **MANTIKSAL KOŞULLAR**
# Eğer değilse gibi yapılarda kullanılan karşılaştırmayı sağlayan mantıksal operatörler olarak bilinmektedir. Bu mantıksal operatörler depişkenlerin içindeki değerlerin eşit olup olmadığını, büyük veya küçük olup olmamasına göre karar vermemizi sağlar.
#
# **iŞARETLER**
# <br>
# **(= =)** -> Eşittir. <br>
# **(! =)** -> Eşit Değildir. <br>
# **(>)**   -> Büyüktür anlamındadır. <br>
# **(<)**   -> Küçüktür anlamındadır. <br>
# **(> =)** -> Büyük ve eşittir anlamındadır. <br>
# **(< =)** -> Küçük ve eşittir anlamındadır. <br>
#
# **NOT:** İşaretler arasında boşluk bırakmayın(== veya != gibi yapın.)
#
# 2. **İKİ NOKTA ÜST ÜSTENİN ANLAMI**
# İki nokta üst üste Python'da altındaki satırın üstteki satırın önemli
# komutları olduğunu göstermektedir.<br>
# **Örneğin**
# Koşul:
#   Koşulun sağlandığında çalışacak kod.
#
# ```
# if sayi == 1:
#   print("sayinin değeri 1'dir.")
# ```
# **DİKKAT:** İki nokta üst üste koyulduktan sonra alttaki satır dört boşlukla  **yazılıyorsa**.

# %%
# Cinsiyet e veya E olursa erkek
# Cinsiyet k veya K olursa kadın
cinsiyet = "k"
if cinsiyet == "k" or cinsiyet == "K": # or veya anlamına gelmektedir
  print("Merhaba Hanımefendi")
#elif ise else if anlamına gelmektedir.
elif cinsiyet == "e" or cinsiyet == "E":
  print("Merhaba Beyefendi")
else:
  print("Lütfen cinsiyetinzi blirtiniz")
# Out:
# Merhaba Hanımefendi

# %%
# Sayılarda Koşullarda kullanılabilir.
# Girdiğimizde sayı 1 ile 100 arasında mı bunu kontrol edelim.
sayi = int(input("Lütfen bir sayi giriniz."))
if sayi >= 1 and sayi <= 100:
  print("Sayi 1 ile 100 arasindadir.")
else:
  print("Sayi 1 ile 100 arasinda degildir.")
# Out:
# Lütfen bir sayi giriniz.101
# Sayi 1 ile 100 arasinda degildir.

# %%
#Kullanıcının girdiği isim "Haşmet" veya "haşmet" ise kullanıcıya diğer bir soru sor.
#Diğer soru ise soyadı "Dayı" veya "dayı" ise kullanıcının girişine izin veren yazıyı yazdırın.
isim = input("Lütfen isminizi giriniz.")
if isim == "Haşmet" or isim == "haşmet":
  soyad = input("Lütfen soyadınızı giriniz.")
  if soyad == "Dayı" or soyad == "dayı":
    print("Hoşgeldiniz")
  else:
    print("Lütfen tekrar deneyiniz.")
else:
  print("Lütfen tekrar deneyiniz.")
# Out:
# Lütfen isminizi giriniz.haşmet
# Lütfen soyadınızı giriniz.ooo
# Lütfen tekrar deneyiniz.

# %% [markdown]
# #Ödev

# %%
sayi = int(input("Lütfen bir sayi giriniz. 1,2,3 veya 0 olabilir."))
if sayi == 1:
  print("https://www.youtube.com/watch?v=jo5r22VPbeo&t=69s")
elif sayi == 2:
  print("https://www.youtube.com/watch?v=hviWaUHUBVM&t=12s")
elif sayi == 3:
  print("https://www.youtube.com/watch?v=yykUppzbuy4")
elif sayi == 0:
  print("kys")
elif sayi == -1:
  print("https://www.sega-dreamcast-info-games-preservation.com/en/unreleased-half-life-dreamcast-early-prototype-history")
elif sayi > 3:
  print("Lütfen tekrar deneyiniz.")
# Out:
# Lütfen bir sayi giriniz. 1,2,3 veya 0 olabilir.-1
# https://www.sega-dreamcast-info-games-preservation.com/en/unreleased-half-life-dreamcast-early-prototype-history

# %%
taban = int(input("Lütfen tabanı yazınız"))
yukseklik = int(input("Lütfen yüksekliğini yazınız"))
print(taban * yukseklik / 2)
print("https://www.youtube.com/watch?v=VY97yEeRg6o&pp=ygUFYWJydW0%3D")
# Out:
# Lütfen tabanı yazınız10
# Lütfen yüksekliğini yazınız45
# 225.0
# https://www.youtube.com/watch?v=VY97yEeRg6o&pp=ygUFYWJydW0%3D

# %%
yarıcap = int(input("Lütfen yarıçapı yazınız"))
print(yarıcap * yarıcap * 3.14)
print("https://battlelog.battlefield.com/bf4/soldier/ligmgamer/stats/1009435180156/pc/")
# Out:
# Lütfen yarıçapı yazınız13
# 530.66
# https://battlelog.battlefield.com/bf4/soldier/ligmgamer/stats/1009435180156/pc/

# %% [markdown]
# #If-Else Yapısı 2: ELIF'in Dönüşü
# ---
# **Elif** aslında **Else-if** anlamına gelen, yukarıdakı koşul değilse eğer deyip çalıştırdığımız başka bir koşul anlamına gelir. Diğer programlama deillerinde **else if** diyerek yazılan ama Python'da kısadan **elif** yazdıktan sonra yine else deyimi kullanılabilir.

# %%
print("VakıfBank'a Hoşgeldiniz!")
print("Dahili numarayı biliyorsanız tuşlayın")
print("Çalıntı kredi kartı işlemleri için 1'i, \n")
print("Fatura hesap kesim bilgileri için 2'yi, \n")
print("Hesap kesim tarihini öğrenmek için 4'ü, \n")
print("Otomatik ödeme talimatı oluşturmak için 5'i, \n")
print("Menüyü tekrar dinlemek için 9'u tuşlayınız.")
islem_secimi = int(input("Aşağıdaki işlemlerden birini tuşlayınız."))
if (islem_secimi == 1):
  print("Kredi kartınızın son dört hanesini giriniz.")
  son_dort_no = int(input("Lütfen işlem notlarını giriniz:"))
  kart_sifre = int(input("Lütfen kartınızın şifresini giriniz:"))
  print("Kartınızı bloke ettik. Rica ederiz.")
elif (islem_secimi == 2):
  fatura_abonman_no = int(input("Lütfen fatura abonman numaranızı giriniz:"))
  if (fatur_abone_no == 1234):
    islem_odensin_mi = False
    odeme_yapilsin_mi = input("238 TL'lik bir su faturanız var. Ödeyelim mi (E/H)")
    if (odeme_yapilsin_mi == "E" or odeme_yapilsin_mi == "e"):
      islem_odensin_mi = True
      if (islem_densin_mi == True): print("Ödeme tamamlandı. Rica ederiz.")
    else: print("Ödemeyi ertelediniz. İyi günler!")
  else: print("Abonman numarasını yanlış girdiniz. İyi günler!")
elif(islem-secimi == 3):
  kredi_miktar =int(input("Lütfen istediğininz kredi mikatarını TL cinsinden tuşlayınız."))
  if(kredi_miktar <= 5000):
    print("Krediniz hazır! En yakın ATM'den alabilirsiniz.")
  elif(islem_secimi > 5000):
    print("Girdiğiniz kredi miktarı çok fazla olduğundan işlem yapamıyoruz.")
    print("Lütfen en yakın şubeden kredi kartı işleminizi gerçekleştiriniz.")
elif(islem_secimi == 5):
  fatura_ad = input("Fatura adınızı giriniz. Lütfen küçük harflerle yazınız:")
  if(fatura_ad == "su" or fatura_ad == "elektrik" or fatura_ad == "doğalgaz"):
    print("Faturanıza otomatik ödeme talimatı verdiniz. İyi günler!")
elif(islem_secimi == 9):
  print("Programı tekrar çalıştırınız!")
else:
  print("Hçbirşey seçilmedi! Arivederci!")
# Out:
# VakıfBank'a Hoşgeldiniz!
# Dahili numarayı biliyorsanız tuşlayın
# Çalıntı kredi kartı işlemleri için 1'i,
#
# Fatura hesap kesim bilgileri için 2'yi,
#
# Hesap kesim tarihini öğrenmek için 4'ü,
#
# Otomatik ödeme talimatı oluşturmak için 5'i,
#
# Menüyü tekrar dinlemek için 9'u tuşlayınız.
# Aşağıdaki işlemlerden birini tuşlayınız.1
# Kredi kartınızın son dört hanesini giriniz.
# Lütfen işlem notlarını giriniz:3223
# Lütfen kartınızın şifresini giriniz:4
# Kartınızı bloke ettik. Rica ederiz.

# %% [markdown]
# ##Sömestir Tatil Dönüşü Ödevi
# ---
# Evet, 8 Şubat'taki ders öncesine minik bir hatırlatma yapmak için size bir ödev veriyorum.
#
# **ÖDEV:** Kullanıcı bilgisayardan sınav notunu girecek. Eğer notu 50'den düşük ise Ekrana "KALDINIZ" 50'den yüsek ise "DERSTEN GEÇTİN! HADİ YİNE İYİSİN!" yazan programı yazdırınız.
#
# **ÖNEMLİ NOT**
# Program akışı şu şekilde olacak:
# 1- Kullanıcıya notunu girmesini isteyeceksiniz.
# 2- Kullancının klavyeden girdiği notu, "not" adında bir değişkenin içine atacaksınız.
# 3- Değişkenin içnideki değerin 50'den düşük mü yoksa yüksek mi olduğunu if-else yapısı ile kontrol edeceksiniz.
# 4- Algoritma akışını öğretmeniniz çok net bir şekilde yazdığına göre bunu yaparsınız bence. 😀
# 5- Eğer bunu bir kişi bile yapmadan gelirse mola da oyun oynayabileceğinizi sanmıyorum. 🕺
# 6- KOLAY GELSİN!!!!!!

# %% [markdown]
# 85-100 -> Pekiyi.
# 84-70 -> İyi. <br>
# 69-50 -> Orta.
# 49-0 -> Kaldın.
# else: -> "Lütfen 0-100 arası not giriniz"
